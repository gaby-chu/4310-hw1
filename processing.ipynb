# %%
import pandas as pd

# %%
data = pd.read_csv("Street_Tree_List-2022-01-30_FILTERED.csv")

# %%
data
# Out:
#        TreeID    qLegalStatus  \
# 0      200311  DPW Maintained
# 1       10425  DPW Maintained
# 2       43163  DPW Maintained
# 3      188921  DPW Maintained
# 4         643  DPW Maintained
# ...       ...             ...
# 37113  141243  DPW Maintained
# 37114  203553  DPW Maintained
# 37115   61778  DPW Maintained
# 37116  190242  DPW Maintained
# 37117  192307  DPW Maintained
#
#                                                 qSpecies  \
# 0      Liquidambar styraciflua 'Rotundiloba' :: Round...
# 1           Schinus terebinthifolius :: Brazilian Pepper
# 2                 Acacia melanoxylon :: Blackwood Acacia
# 3              Callistemon citrinus :: Lemon Bottlebrush
# 4                     Ficus microcarpa :: Chinese Banyan
# ...                                                  ...
# 37113          Magnolia grandiflora :: Southern Magnolia
# 37114               Agonis flexuosa :: Peppermint Willow
# 37115                Eriobotrya deflexa :: Bronze Loquat
# ...

# %%
data.qSiteInfo.unique()
# Out:
# array(['Sidewalk: Curb side : Yard', 'Sidewalk: Curb side : Cutout',
#        'Sidewalk: Property side : Yard', 'Back Yard : Yard',
#        'Side Yard : Yard', 'Front Yard : Yard', 'Median : Yard',
#        'Median : Cutout', 'Sidewalk: Curb side : Pot', 'Median :',
#        'Sidewalk: Property side : Cutout', 'unknown : Yard',
#        'Unaccepted Street : Yard', 'Front Yard : Pot',
#        'Side Yard : Cutout', ': Yard', 'Front Yard : Cutout',
#        'Sidewalk: Property side : Pot', ': Cutout',
#        'Unaccepted Street : Cutout', 'Back Yard : Cutout',
#        'Sidewalk: Curb side :', 'Sidewalk: Curb side : Hanging Pot'],
#       dtype=object)

# %%
data.qSpecies.unique().size
# Out:
# 419

# %%
species_counts = data.qSpecies.value_counts()
species_counts
# Out:
# Platanus x hispanica :: Sycamore: London Plane                       2633
# Metrosideros excelsa :: New Zealand Xmas Tree                        1937
# Lophostemon confertus :: Brisbane Box                                1727
# Pittosporum undulatum :: Victorian Box                               1669
# Tristaniopsis laurina :: Swamp Myrtle                                1577
#                                                                      ...
# Archontophoenix myolensis :: Myola palm                                 1
# Pinus torreyana :: Torrey Pine                                          1
# Diospyros kaki :: Persimmon                                             1
# Prunus sargentii 'Columnaris' :: Sargent Cherry Tree 'Columnaris'       1
# Platanus x hispanica 'Bloodgood' :: Bloodgood London Plane              1
# Name: qSpecies, Length: 419, dtype: int64

# %%
most_common_species = species_counts[species_counts > 500].index

# %%
most_common_species
# Out:
# Index(['Platanus x hispanica :: Sycamore: London Plane',
#        'Metrosideros excelsa :: New Zealand Xmas Tree',
#        'Lophostemon confertus :: Brisbane Box',
#        'Pittosporum undulatum :: Victorian Box',
#        'Tristaniopsis laurina :: Swamp Myrtle',
#        'Ficus microcarpa nitida 'Green Gem' :: Indian Laurel Fig Tree 'Green Gem'',
#        'Magnolia grandiflora :: Southern Magnolia',
#        'Prunus cerasifera :: Cherry Plum',
#        'Arbutus 'Marina' :: Hybrid Strawberry Tree',
#        'Prunus serrulata 'Kwanzan' :: Kwanzan Flowering Cherry',
#        'Acacia melanoxylon :: Blackwood Acacia', 'Olea europaea :: Olive Tree',
#        'Corymbia ficifolia :: Red Flowering Gum', 'Maytenus boaria :: Mayten',
#        'Callistemon citrinus :: Lemon Bottlebrush',
#        'Ginkgo biloba :: Maidenhair Tree',
#        'Pyrus calleryana :: Ornamental Pear',
#        'Ulmus parvifolia :: Chinese Elm'],
#       dtype='object')

# %%
len(most_common_species)
# Out:
# 18

# %%
data2 = data[data.qSpecies.isin(most_common_species)]

# %%
data2
# Out:
#        TreeID    qLegalStatus  \
# 2       43163  DPW Maintained
# 3      188921  DPW Maintained
# 6      133773  DPW Maintained
# 8      209974  DPW Maintained
# 9        9999  DPW Maintained
# ...       ...             ...
# 37108  214294  DPW Maintained
# 37111   54849  DPW Maintained
# 37112   21647  DPW Maintained
# 37113  141243  DPW Maintained
# 37116  190242  DPW Maintained
#
#                                                 qSpecies  \
# 2                 Acacia melanoxylon :: Blackwood Acacia
# 3              Callistemon citrinus :: Lemon Bottlebrush
# 6         Platanus x hispanica :: Sycamore: London Plane
# 8          Metrosideros excelsa :: New Zealand Xmas Tree
# 9      Ficus microcarpa nitida 'Green Gem' :: Indian ...
# ...                                                  ...
# 37108                   Prunus cerasifera :: Cherry Plum
# 37111                   Prunus cerasifera :: Cherry Plum
# 37112          Magnolia grandiflora :: Southern Magnolia
# ...

# %%
shortname = []
for x in data2.qSpecies:
    shortname.append(x.split(":: ")[1])
shortname[1]
# Out:
# 'Lemon Bottlebrush'

# %%
most_common_species2
# Out:
# Index(['Platanus x hispanica :: Sycamore: London Plane',
#        'Metrosideros excelsa :: New Zealand Xmas Tree',
#        'Lophostemon confertus :: Brisbane Box',
#        'Pittosporum undulatum :: Victorian Box',
#        'Tristaniopsis laurina :: Swamp Myrtle',
#        'Ficus microcarpa nitida 'Green Gem' :: Indian Laurel Fig Tree 'Green Gem'',
#        'Magnolia grandiflora :: Southern Magnolia',
#        'Prunus cerasifera :: Cherry Plum',
#        'Arbutus 'Marina' :: Hybrid Strawberry Tree',
#        'Prunus serrulata 'Kwanzan' :: Kwanzan Flowering Cherry'],
#       dtype='object')

# %%
most_common_species2 = species_counts[species_counts > 820].index

# %%
most_common_species2
# Out:
# Index(['Platanus x hispanica :: Sycamore: London Plane',
#        'Metrosideros excelsa :: New Zealand Xmas Tree',
#        'Lophostemon confertus :: Brisbane Box',
#        'Pittosporum undulatum :: Victorian Box',
#        'Tristaniopsis laurina :: Swamp Myrtle',
#        'Ficus microcarpa nitida 'Green Gem' :: Indian Laurel Fig Tree 'Green Gem'',
#        'Magnolia grandiflora :: Southern Magnolia',
#        'Prunus cerasifera :: Cherry Plum',
#        'Arbutus 'Marina' :: Hybrid Strawberry Tree',
#        'Prunus serrulata 'Kwanzan' :: Kwanzan Flowering Cherry'],
#       dtype='object')

# %%
most_common_species2.size
# Out:
# 10

# %%
data3
# Out:
#        TreeID    qLegalStatus  \
# 6      133773  DPW Maintained
# 8      209974  DPW Maintained
# 9        9999  DPW Maintained
# 13      29149  DPW Maintained
# 15     134799  DPW Maintained
# ...       ...             ...
# 37108  214294  DPW Maintained
# 37111   54849  DPW Maintained
# 37112   21647  DPW Maintained
# 37113  141243  DPW Maintained
# 37116  190242  DPW Maintained
#
#                                                 qSpecies  \
# 6         Platanus x hispanica :: Sycamore: London Plane
# 8          Metrosideros excelsa :: New Zealand Xmas Tree
# 9      Ficus microcarpa nitida 'Green Gem' :: Indian ...
# 13                 Lophostemon confertus :: Brisbane Box
# 15        Platanus x hispanica :: Sycamore: London Plane
# ...                                                  ...
# 37108                   Prunus cerasifera :: Cherry Plum
# 37111                   Prunus cerasifera :: Cherry Plum
# 37112          Magnolia grandiflora :: Southern Magnolia
# ...

# %%
data3 = data[data.qSpecies.isin(most_common_species2)]

# %%
data3
# Out:
#        TreeID    qLegalStatus  \
# 6      133773  DPW Maintained
# 8      209974  DPW Maintained
# 9        9999  DPW Maintained
# 13      29149  DPW Maintained
# 15     134799  DPW Maintained
# ...       ...             ...
# 37108  214294  DPW Maintained
# 37111   54849  DPW Maintained
# 37112   21647  DPW Maintained
# 37113  141243  DPW Maintained
# 37116  190242  DPW Maintained
#
#                                                 qSpecies  \
# 6         Platanus x hispanica :: Sycamore: London Plane
# 8          Metrosideros excelsa :: New Zealand Xmas Tree
# 9      Ficus microcarpa nitida 'Green Gem' :: Indian ...
# 13                 Lophostemon confertus :: Brisbane Box
# 15        Platanus x hispanica :: Sycamore: London Plane
# ...                                                  ...
# 37108                   Prunus cerasifera :: Cherry Plum
# 37111                   Prunus cerasifera :: Cherry Plum
# 37112          Magnolia grandiflora :: Southern Magnolia
# ...

# %%
new = []
for x in data3.qSpecies:
    new.append(x.split(":: ")[1])
new[1]
# Out:
# 'New Zealand Xmas Tree'

# %%
data3.qSpecies = new
data3
# Out:
# /var/folders/yf/2m7vdqqs0v16g0qhwl70d1700000gn/T/ipykernel_23678/2048271591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.qSpecies = new
#        TreeID    qLegalStatus                            qSpecies  \
# 6      133773  DPW Maintained              Sycamore: London Plane
# 8      209974  DPW Maintained               New Zealand Xmas Tree
# 9        9999  DPW Maintained  Indian Laurel Fig Tree 'Green Gem'
# 13      29149  DPW Maintained                        Brisbane Box
# 15     134799  DPW Maintained              Sycamore: London Plane
# ...       ...             ...                                 ...
# 37108  214294  DPW Maintained                         Cherry Plum
# ...

# %%
data3.to_csv("filtered_data.csv")

# %%
data3.qSpecies.count()
# Out:
# 15555

# %%
most_common_species2
# Out:
# Index(['Platanus x hispanica :: Sycamore: London Plane',
#        'Metrosideros excelsa :: New Zealand Xmas Tree',
#        'Lophostemon confertus :: Brisbane Box',
#        'Pittosporum undulatum :: Victorian Box',
#        'Tristaniopsis laurina :: Swamp Myrtle',
#        'Ficus microcarpa nitida 'Green Gem' :: Indian Laurel Fig Tree 'Green Gem'',
#        'Magnolia grandiflora :: Southern Magnolia',
#        'Prunus cerasifera :: Cherry Plum',
#        'Arbutus 'Marina' :: Hybrid Strawberry Tree',
#        'Prunus serrulata 'Kwanzan' :: Kwanzan Flowering Cherry'],
#       dtype='object')

# %%
data3['qSpecies'].loc[data3['qSpecies'] == 'Sycamore: London Plane'].count()
# Out:
# 2633

# %%
data3['qSpecies'].loc[data3['qSpecies'] == "Kwanzan Flowering Cherry"].count()
# Out:
# 841

# %%
species_counts[species_counts > 820]
# Out:
# Platanus x hispanica :: Sycamore: London Plane                               2633
# Metrosideros excelsa :: New Zealand Xmas Tree                                1937
# Lophostemon confertus :: Brisbane Box                                        1727
# Pittosporum undulatum :: Victorian Box                                       1669
# Tristaniopsis laurina :: Swamp Myrtle                                        1577
# Ficus microcarpa nitida 'Green Gem' :: Indian Laurel Fig Tree 'Green Gem'    1425
# Magnolia grandiflora :: Southern Magnolia                                    1377
# Prunus cerasifera :: Cherry Plum                                             1306
# Arbutus 'Marina' :: Hybrid Strawberry Tree                                   1063
# Prunus serrulata 'Kwanzan' :: Kwanzan Flowering Cherry                        841
# Name: qSpecies, dtype: int64

# %%
new_counts = data3.qSpecies.value_counts()
new_counts = pd.DataFrame(new_counts).reset_index()
new_counts = new_counts.rename(columns = {"index":"species", "qSpecies":"count"})

# %%
new_counts
# Out:
#                               species  count
# 0              Sycamore: London Plane   2633
# 1               New Zealand Xmas Tree   1937
# 2                        Brisbane Box   1727
# 3                       Victorian Box   1669
# 4                        Swamp Myrtle   1577
# 5  Indian Laurel Fig Tree 'Green Gem'   1425
# 6                   Southern Magnolia   1377
# 7                         Cherry Plum   1306
# 8              Hybrid Strawberry Tree   1063
# 9            Kwanzan Flowering Cherry    841

# %%
type(new_counts['count'][1])
# Out:
# numpy.int64

# %%
new_counts.to_csv("counts.csv")

# %%
data3
# Out:
#        TreeID    qLegalStatus                            qSpecies  \
# 6      133773  DPW Maintained              Sycamore: London Plane
# 8      209974  DPW Maintained               New Zealand Xmas Tree
# 9        9999  DPW Maintained  Indian Laurel Fig Tree 'Green Gem'
# 13      29149  DPW Maintained                        Brisbane Box
# 15     134799  DPW Maintained              Sycamore: London Plane
# ...       ...             ...                                 ...
# 37108  214294  DPW Maintained                         Cherry Plum
# 37111   54849  DPW Maintained                         Cherry Plum
# 37112   21647  DPW Maintained                   Southern Magnolia
# 37113  141243  DPW Maintained                   Southern Magnolia
# 37116  190242  DPW Maintained  Indian Laurel Fig Tree 'Green Gem'
#
#                    qAddress  SiteOrder                     qSiteInfo  \
# 6             2460 Scott St        1.0  Sidewalk: Curb side : Cutout
# ...

# %%
data3
# Out:
#        TreeID    qLegalStatus                            qSpecies  \
# 6      133773  DPW Maintained              Sycamore: London Plane
# 8      209974  DPW Maintained               New Zealand Xmas Tree
# 9        9999  DPW Maintained  Indian Laurel Fig Tree 'Green Gem'
# 13      29149  DPW Maintained                        Brisbane Box
# 15     134799  DPW Maintained              Sycamore: London Plane
# ...       ...             ...                                 ...
# 37108  214294  DPW Maintained                         Cherry Plum
# 37111   54849  DPW Maintained                         Cherry Plum
# 37112   21647  DPW Maintained                   Southern Magnolia
# 37113  141243  DPW Maintained                   Southern Magnolia
# 37116  190242  DPW Maintained  Indian Laurel Fig Tree 'Green Gem'
#
#                    qAddress  SiteOrder                     qSiteInfo  \
# 6             2460 Scott St        1.0  Sidewalk: Curb side : Cutout
# ...

# %%
data3.to_csv("clean_data.csv")
